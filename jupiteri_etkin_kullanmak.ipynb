# %% [markdown]
# # Jupiter'i Etkin Kullanmak

# %% [markdown]
# Jupyter's start-up directory
# Komut satırına: jupyter notebook
# Bu adres gelecek: http://localhost:8892/tree
# Bu adres değiştirilebilir, hem windows 10 hem mac için: https://stackoverflow.com/questions/35254852/how-to-change-the-jupyter-start-up-folder
#
# Mac için: içinde çalışılmak istenilen dizine terminalden gidilir.
# Bu dizin altında şu kod yazılır: jupyter notebook

# %% [markdown]
# # Kısayol Tuşları

# %% [markdown]
# Notebook verdiğimiz kısa yolları iki ayrı bileşen için ayrı ayrı algılar. Birisi hücreler için kullanacağımız kısa yol tuşları diğer hücrelerin dışında iken kullanacağımız kısayol tuşları. Örneğin hücre içinde bir şey kopyalayıp yapıştırmak istediğimizde bunu ctrl c ctrl v kombinasyonları ile yapabiliriz.
# Bu  işlemi hücre dışında hücrelere yönelik olarak yapmak istediğimizde c ve v duşlarına basmamız yeterli olacaktır. Dolayısıyla kısayol tuşlarını öğrenirken de buna göre öğrenmekte fayda var.
#
# Yukarı aşağı oklar ile hücreler arasında gezinilir.
# A: satırın üstüne boş satır ekler.
# B: satırın altına boş satır ekler.
# M: seçili hücreyi markdowna çevirir.
# Y: seçili hücreeyi code hücresine çevirir.
# D+D: iki defa D ye basıldığında üzerinde olunan hücre silinir.
# Z: işlemi geri alır.
# Shift + yön tuşları : birden fazla hücre seçmek için.
# Shift + m: seçili hücreleri birleştirir.

# %% [markdown]
# # Markdown

# %% [markdown]
# Normal bir yazı bu yazı.
#
# Bu **kalın yazıdır**, bu da _italik_ yazıdır.
#
# Liste elemanları:
#
# * Eleman1
# * Eleman2
#  * Bu da alt eleman
#  * Bu da ikinci alt eleman
#
#
#
# 1. Numaralı liste
# 2. Numaralı liste
#
# Burada bir link var: [tıkla](https://www.veribilimi.co)
#
# Kod ifade etmek için: `sum()`
#
# Kod bloğu ya da girintili ifade için:
#
# ```
# mean()
#
# ```
#
# Aynı işlemi 4 boşluk ile de ifade edebiliriz:
#
#     foo()
#
# Resim eklemek: ![Alt text](https://www.example.com/image.jpg)
#
# #https://www.dataquest.io/blog/jupyter-notebook-tutorial/

# %% [markdown]
# # Hücre özelinde ayarlamalar yapmak
#
# It's common to start off with a code cell specifically for imports and setup, so that if you choose to add or change anything, you can simply edit and re-run the cell without causing any side-effects.

# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="darkgrid")

# %% [markdown]
# # Notebook'a resim koymak

# %%
#pwd
from IPython.display import Image
#from IPython.core.display import HTML

PATH = "/Users/mvahit/Desktop/python_ile_veri_bilimi_ve_makine_ogrenimi/jupiter/"
Image(filename = PATH + "a.png", width=300, height=300)

# %%
#![title]("/a.png")

# %% [markdown]
# # Variable Explorer Eklentisi
# https://github.com/lckr/jupyterlab-variableInspector
#
# Notebooktan yuklemek için:
#
# !jupyter labextension install @lckr/jupyterlab_variableinspector
#
# Console'dan yüklemek için:
#
# jupyter labextension install @lckr/jupyterlab_variableinspector

# %% [markdown]
# # Değişkenleri Görmek

# %%
who
# Out:
# K	 NamespaceMagics	 get_ipython	 getsizeof	 json	 np	 pd	 pyspark	 tf

# %% [markdown]
# Çeşitki Notlar

# %% [markdown]
# df['Amount'] = pd.to_numeric(df['Amount']) #numerik bilgisi
# movies_df = movies_df.drop_duplicates(keep='first') #satırlardak duplicelerin silinmesi
#
# #replacing all the zeros from revenue and budget cols.
#
# cols = ['budget', 'revenue']
# movies_df[cols] = movies_df[cols].replace(0, np.nan)
#
# #dropping all the rows with na in the columns mentioned above in the list.
# movies_df.dropna(subset=cols, inplace=True)
#
#
# #Changing the data type of the below mentioned columns and
# change_cols=['budget', 'revenue']
# #changing data type
# movies_df[change_cols]=movies_df[change_cols].applymap(np.int64)
# movies_df.dtypes

# %% [markdown]
# Float çıktısının virgülden sonrasını ayarlamak:

# %%
"%.0f" % 10.9999
# Out:
# '11'

# %% [markdown]
# # Kaliteli Çıktı

# %%
# %config InlineBackend.figure_format = 'retina'

# %%
import warnings

with warnings.catch_warnings():
    warnings.filterwarnings("ignore",category=DeprecationWarning)
    import md5, sha

# %%
#İndeksi değişken ismi olarak kaydetmek

#sbar = df.cut.value_counts()
#sbar
#ssbar = pd.DataFrame(sbar)
#ssbar['kategoriler'] = sbar.index
#print(ssbar)
#ssbar.dtypes
# Out:
#              cut kategoriler
# Ideal      21551       Ideal
# Premium    13791     Premium
# Very Good  12082   Very Good
# Good        4906        Good
# Fair        1610        Fair
# cut               int64
# kategoriler    category
# dtype: object

# %% [markdown]
# Jupiter notebooktan kütüphane indirmek:

# %%
#!pip install mlxtend
